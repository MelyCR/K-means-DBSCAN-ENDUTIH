# %% [markdown]
# ## importar librerías

# %%
import pandas as pd #para manejar el dataframe
import numpy as np #para abrir el csv
import matplotlib.pyplot as plt #para graficar 
from sklearn.cluster import KMeans #para clasificar los datos
import sklearn as sk #para normalizar los datos

# %% [markdown]
# ## cargar base de datos

# %%
path='C:/Users/MALIK/Documents/ProgramaDelfin/usuario99-0.csv'
df1 = pd.read_csv(path,encoding='latin',low_memory=False)
df1.head()
# Out:
#    VIV_SEL  HOGAR  N_REN  P6_1  P6_3  P7_1  P7_3  P7_4  P7_5_1  P7_5_2  ...    \
# 0        1      1      4     2     6     1     1     3       2       2  ...
# 1        2      1      1     2     3     2     6    13       3       3  ...
# 2        3      1      1     1     7     1     3    13       2       2  ...
# 3        4      1      1     1     7     1     1     5       2       1  ...
# 4        4      2      1     1     7     1     1     6       2       1  ...
#
#    P8_5  P8_6_1  P8_6_2  P8_8  P8_9  P8_10_1  P8_10_2  CD_ENDUTIH  ENT  P8_7r
# 0     1       1       2     1     1        1        1          14    1      2
# 1     1       1       2     1     2        3        3          14    1      1
# 2     2       1       2     1     3        3        3          14    1      1
# 3     1       2       1     1     1        1        1          14    1      2
# 4     1       2       1     1     1        1        1          14    1      2
#
# [5 rows x 92 columns]

# %% [markdown]
# ## normalizar los datos

# %%
X = sk.preprocessing.normalize(df1, norm='l2', axis=1, copy=True)
X
# Out:
# array([[0.04207032, 0.04207032, 0.16828126, ..., 0.58898443, 0.04207032,
#         0.08414063],
#        [0.06008418, 0.03004209, 0.03004209, ..., 0.42058924, 0.03004209,
#         0.03004209],
#        [0.10078697, 0.03359566, 0.03359566, ..., 0.4703392 , 0.03359566,
#         0.03359566],
#        ...,
#        [0.04633343, 0.01158336, 0.03475007, ..., 0.82241834, 0.37066742,
#         0.18533371],
#        [0.215742  , 0.01135484, 0.03406453, ..., 0.80619379, 0.36335495,
#         0.18167747],
#        [0.1422736 , 0.01185613, 0.01185613, ..., 0.84178546, 0.37939626,
#         0.02371227]])

# %% [markdown]
# ## gráfica de elbow

# %%
distortions = []

for i in range(1,11):
    km = KMeans(n_clusters=i,
                init='k-means++',
                n_init=10,
                max_iter=300,
                random_state=0)
    km.fit(X)
    distortions.append(km.inertia_)

plt.plot(range(1,11), distortions, marker='o')
plt.xlabel('Numero de clusters')
plt.ylabel('Distorsión')
plt.show()

# %%
clusters = KMeans(n_clusters=4,
                    init='k-means++', 
                    max_iter=300,
                    tol=1e-04,
                    n_init=10,
                    random_state=0)  

print(np.unique(clusters.fit_predict(X)))
# Out:
# [0 1 2 3]

# %% [markdown]
# ## gráficar los clusters

# %%
y_km = clusters.fit_predict(X)
plt.scatter(X[y_km==0,0],
          X[y_km==0,1],
          s=50,
          c='lightgreen',
          edgecolor='black',
          marker='o',
          label='cluster 1')
plt.scatter(X[y_km==1,0],
          X[y_km==1,1],
          s=50,
          c='orange',
          edgecolor='black',
          marker='v',
          label='cluster 2')
plt.scatter(X[y_km==2,0],
          X[y_km==2,1],
          s=50,
          c='blue',
          edgecolor='black',
          marker='s',
          label='cluster 3')
plt.scatter(X[y_km==3,0],
          X[y_km==3,1],
          s=50,
          c='yellow',
          edgecolor='black',
          marker='+',
          label='cluster 4')

plt.scatter(clusters.cluster_centers_[:,0],
          clusters.cluster_centers_[:,1],
          s=50,
          c='red',
          marker='*',
          label='centroides')


plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 
# 1         1      1
# 2         1      1
# 3         1      2
# 4         1      2
# 5         1      3
# 6         1      3
# 7         1     16
# 8         1      2
# 9         1      2
# 10        1      2
# 11        1      2
# 12        1      3
# 13        1      2
# 14        1      2
# 15        1      1
# 16        1      1
# 17        1      2
# 18        1      1
# 19        1      1
# 20        1      2
# 21        1      1
# 22        1      1
# 23        1     16
# 24        1      2
# 25        1     16
# 26        1      1
# 27        1      2
# 28        1      1
# 29        1      4
# ...     ...    ...
# 135311   31      3
# 135312   31      3
# 135313   31      1
# 135314   31      1
# 135315   31     16
# 135316   31      1
# 135317   31      2
# 135318   32      5
# 135319   32      1
# 135320   32      2
# 135321   32      1
# 135322   32      2
# 135323   32      4
# 135324   32      1
# 135325   32      1
# 135326   32      2
# 135327   32      5
# 135328   32      1
# 135329   32     16
# 135330   32      7
# 135331   32      1
# 135332   32      1
# 135333   32     16
# 135334   32      1
# 135335   32      1
# 135336   32      2
# 135337   32     16
# 135338   32     16
# 135339   32     16
# 135340   32      2
#
# [135341 rows x 92 columns]

# %% [markdown]
# ## aplicar PCA

# %%
from sklearn import decomposition

# %%
pca = decomposition.PCA(n_components=3)
pca.fit(X)
X = pca.transform(X)

# %% [markdown]
# ## volver a graficar los clusters

# %%
plt.scatter(X[y_km==0,0],
          X[y_km==0,1],
          s=70,
          c='lightgreen',
          edgecolor='black',
          marker='o',
          label='cluster 1')
plt.scatter(X[y_km==1,0],
          X[y_km==1,1],
          s=70,
          c='orange',
          edgecolor='black',
          marker='v',
          label='cluster 2')
plt.scatter(X[y_km==2,0],
          X[y_km==2,1],
          s=70,
          c='blue',
          edgecolor='black',
          marker='s',
          label='cluster 3')
plt.scatter(X[y_km==3,0],
          X[y_km==3,1],
          s=70,
          c='yellow',
          edgecolor='black',
          marker='+',
          label='cluster 4')

plt.scatter(clusters.cluster_centers_[:,0],
          clusters.cluster_centers_[:,1],
          s=50,
          c='red',
          marker='*',
          label='centroides')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## agregar la columna "cluster" al dataset

# %%
self['cluster']=clusters.fit_predict(X)

# %%
self
# Out:
#         VIV_SEL  HOGAR  N_REN  P6_1  P6_3  P7_1  P7_3  P7_4  P7_5_1  P7_5_2  \
# 0             1      1      4     2     6     1     1     3       2       2
# 1             2      1      1     2     3     2     6    13       3       3
# 2             3      1      1     1     7     1     3    13       2       2
# 3             4      1      1     1     7     1     1     5       2       1
# 4             4      2      1     1     7     1     1     6       2       1
# 5             4      3      1     1     7     1     1    12       2       1
# 6             4      4      1     1     7     1     1    12       2       1
# 7             1      1      2     2     2     2     6    13       3       3
# 8             2      1      1     1     7     1     1    10       1       2
# 9             3      1      1     1     7     1     1     6       2       1
# 10            4      1      3     1     7     1     1     5       2       1
# 11            5      1      3     1     7     1     1     3       2       1
# 12            1      1      4     1     7     1     1     8       2       1
# 13            2      1      2     1     7     1     1     2       2       1
# 14            3      1      1     1     7     1     1     1       2       1
# 15            4      1      3     1     7     1     2    13       2       1
# 16            5      1      4     1     7     1     1     4       2       1
# 17            1      1      5     2     1     1     1     1       2       2
# 18            2      1      1     2     2     2     6    13       3       3
# 19            3      1      1     2     2     2     6    13       3       3
# 20            4      1      3     2     3     1     1     1       2       2
# 26       ...          1       2     1     1        1        1          14
# 27       ...          2       1     1     1        2        1          14
# 28       ...          1       2     1     3        3        3          14
# 29       ...          2       1     1     1        1        1          14
# ...      ...        ...     ...   ...   ...      ...      ...         ...
# 135311   ...          1       2     1     1        1        1          71
# 135312   ...          1       2     1     3        3        3          71
# 135313   ...          1       2     2     1        2        1          71
# 135314   ...          1       2     2     1        2        1          71
# 135315   ...          3       3     3     3        3        3          71
# 135316   ...          1       2     1     3        3        3          71
# 135317   ...          1       2     1     3        3        3          71
# 135318   ...          1       2     1     1        1        1          32
# 135319   ...          1       2     1     1        1        1          32
# 135320   ...          1       2     1     1        1        1          32
# 135321   ...          1       2     2     1        1        1          32
# 135322   ...          1       2     1     1        1        1          32
# 135323   ...          2       1     2     1        1        1          32
# 135324   ...          1       2     1     1        1        1          32
# 135325   ...          1       2     1     3        3        3          32
# 135326   ...          1       2     1     1        1        1          32
# 135327   ...          2       1     1     1        1        1          32
# 135328   ...          1       2     1     1        2        1          32
# 135329   ...          3       3     3     3        3        3          32
# 135330   ...          2       1     1     1        1        1          32
# 135331   ...          1       2     3     1        1        1          32
# 135332   ...          1       2     1     3        3        3          71
# 135333   ...          3       3     3     3        3        3          71
# 135334   ...          1       2     1     1        2        1          71
# 135335   ...          1       2     1     1        1        2          71
# 135336   ...          1       2     1     1        1        1          71
# 135337   ...          3       3     3     3        3        3          71
# 135338   ...          3       3     3     3        3        3          71
# 135339   ...          3       3     3     3        3        3          71
# 135340   ...          1       2     1     2        3        3          71
#
#         ENT  P8_7r  cluster
# 0         1      2        1
# 1         1      1        1
# 2         1      1        1
# 3         1      2        1
# 4         1      2        1
# 5         1      3        1
# 6         1      3        1
# 7         1     16        1
# 8         1      2        1
# 9         1      2        1
# 10        1      2        1
# 11        1      2        1
# 12        1      3        1
# 13        1      2        1
# 14        1      2        1
# 15        1      1        1
# 16        1      1        1
# 17        1      2        1
# 18        1      1        1
# 19        1      1        1
# 20        1      2        1
# 21        1      1        1
# 22        1      1        1
# 23        1     16        1
# 24        1      2        1
# 25        1     16        1
# 26        1      1        1
# 27        1      2        1
# 28        1      1        1
# 29        1      4        1
# ...     ...    ...      ...
# 135311   31      3        2
# 135312   31      3        2
# 135313   31      1        2
# 135314   31      1        2
# 135315   31     16        2
# 135316   31      1        2
# 135317   31      2        2
# 135318   32      5        0
# 135319   32      1        0
# 135320   32      2        0
# 135321   32      1        0
# 135322   32      2        0
# 135323   32      4        0
# 135324   32      1        0
# 135325   32      1        0
# 135326   32      2        0
# 135327   32      5        0
# 135328   32      1        0
# 135329   32     16        0
# 135330   32      7        0
# 135331   32      1        0
# 135332   32      1        2
# 135333   32     16        2
# 135334   32      1        2
# 135335   32      1        2
# 135336   32      2        2
# 135337   32     16        2
# 135338   32     16        2
# 135339   32     16        2
# 135340   32      2        2
#
# [135341 rows x 93 columns]

# %%
self.cluster.value_counts()
# Out:
# 2    71577
# 0    26190
# 3    19394
# 1    18180
# Name: cluster, dtype: int64

# %%
self['cluster'].isnull().any().any()
# Out:
# False

# %% [markdown]
# ## exportar la nueva base de datos como csv

# %%
self.to_csv('C:/Users/MALIK/Documents/ProgramaDelfin/UsuarioKMeansCluster.csv',index=False)

# %% [markdown]
# ## Importar librerías

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt #para graficar 
from sklearn.cluster import KMeans #para clasificar los datos
import sklearn as sk #para normalizar los datos

# %% [markdown]
# ## cargar la base de datos

# %%
path='C:/Users/MALIK/Documents/ProgramaDelfin/usuario99-0.csv'
df2 = pd.read_csv(path,encoding='latin',low_memory=False)
df2.head()
# Out:
#    VIV_SEL  HOGAR  N_REN  P6_1  P6_3  P7_1  P7_3  P7_4  P7_5_1  P7_5_2  ...    \
# 0        1      1      4     2     6     1     1     3       2       2  ...
# 1        2      1      1     2     3     2     6    13       3       3  ...
# 2        3      1      1     1     7     1     3    13       2       2  ...
# 3        4      1      1     1     7     1     1     5       2       1  ...
# 4        4      2      1     1     7     1     1     6       2       1  ...
#
#    P8_5  P8_6_1  P8_6_2  P8_8  P8_9  P8_10_1  P8_10_2  CD_ENDUTIH  ENT  P8_7r
# 0     1       1       2     1     1        1        1          14    1      2
# 1     1       1       2     1     2        3        3          14    1      1
# 2     2       1       2     1     3        3        3          14    1      1
# 3     1       2       1     1     1        1        1          14    1      2
# 4     1       2       1     1     1        1        1          14    1      2
#
# [5 rows x 92 columns]

# %% [markdown]
# ## normalizar los datos

# %%
X= sk.preprocessing.normalize(df2, norm='l2', axis=1, copy=True)

X = StandardScaler().fit_transform(X)

# %% [markdown]
# ## Aplicar el algoritmo DBSCAN

# %%
# Compute DBSCAN
db = DBSCAN(eps=0.3, min_samples=90).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# %%
np.unique(labels)
# Out:
# array([-1,  0,  1,  2], dtype=int64)

# %% [markdown]
# ## imprimir la cantidad de clusters

# %%
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print('Estimated number of clusters: %d' % n_clusters_)
# Out:
# Estimated number of clusters: 3

# %%
y_db=db.fit_predict(X)

# %% [markdown]
# ## graficar los clusters

# %%
plt.scatter(X[y_db==-1,0],
            X[y_db==-1,1],
            c='black',
            edgecolor='black',
            marker='.',
            s=40,
            label='noise')
plt.scatter(X[y_db==0,0],
            X[y_db==0,1],
            c='r',
            edgecolor='black',
            marker='o',
            s=70,
            label='cluster 1')
plt.scatter(X[y_db==1,0],
            X[y_db==1,1],
            c='blue',
            edgecolor='black',
            marker='+',
            s=70,
            label='cluster 2')
plt.scatter(X[y_db==2,0],
            X[y_db==2,1],
            c='green',
            edgecolor='black',
            marker='v',
            s=70,
            label='cluster 3')



plt.legend()
plt.show()

# %% [markdown]
# ## Aplicar PCA a DBSCAN

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components=2)
pca.fit(X)
X = pca.transform(X)

# %% [markdown]
# ## Graficar los clusters

# %%
plt.scatter(X[y_db==-1,0],
            X[y_db==-1,1],
            c='black',
            edgecolor='black',
            marker='.',
            s=40,
            label='noise')
plt.scatter(X[y_db==0,0],
            X[y_db==0,1],
            c='r',
            edgecolor='black',
            marker='o',
            s=70,
            label='cluster 1')
plt.scatter(X[y_db==1,0],
            X[y_db==1,1],
            c='blue',
            edgecolor='black',
            marker='+',
            s=70,
            label='cluster 2')
plt.scatter(X[y_db==2,0],
            X[y_db==2,1],
            c='green',
            edgecolor='black',
            marker='v',
            s=70,
            label='cluster 3')



plt.legend()
plt.show()
